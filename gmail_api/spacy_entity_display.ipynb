# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import base64
import os
import json
import ast
from bs4 import BeautifulSoup

# %%
df = pd.read_csv("emails_dir/emails_parsed.csv")
df
# Out:
#       Unnamed: 0                id          threadId  \
# 0              0  189de4921223c782  189de4921223c782
# 1              1  189de46892b19d42  189de46892b19d42
# 2              2  189de467e12b5f9d  189de467e12b5f9d
# 3              3  189de293a9a424ae  189de293a9a424ae
# 4              4  189de0e819fc210b  189de0e819fc210b
# ...          ...               ...               ...
# 2224        2224  13ee5fadbd24dcdb  13ee5fadbd24dcdb
# 2225        2225  13ecd429e3657c7a  13ecd429e3657c7a
# 2226        2226  13eac280e2236284  13eac280e2236284
# 2227        2227  13e5c04b5626bdd6  13e5c04b5626bdd6
# 2228        2228  13da9cc797e5c2f6  13da9cc797e5c2f6
#
#                                                labelIds  \
# 0                         ['CATEGORY_UPDATES', 'INBOX']
# 1     ['Label_86509504764210579', 'CATEGORY_UPDATES'...
# 2     ['Label_86509504764210579', 'Label_68765890314...
# 3     ['Label_4360772061833180153', 'IMPORTANT', 'CA...
# ...

# %%
for elem in df["body"].sample(100):
    print(elem)
    print("----" * 20)
# Out:
# Practo Dear Aayush Agrawal , Wish you a very Happy Birthday! It's time to celebrate another trip you made around the sun! May this special day mark the beginning of a healthier life filled with happiness and prosperity. Cheers, Dr Ravinder . Dentalign - Whitefield Ground Floor, Sai Gandhi Square, ramagondanahalli Opp Adarsh Palm Meadows Bangalore 560066 India Phone : +919945033372 Email : dental.whitefield@gmail.com Website : www.dentalign.in
# --------------------------------------------------------------------------------
# PFA PFA
# --------------------------------------------------------------------------------
# hi hi
# --------------------------------------------------------------------------------
# nan
# --------------------------------------------------------------------------------
# ...

# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")
doc_ls = []
for elem in df["body"].dropna().sample(20).values.tolist():
    doc = nlp(elem)
    doc_ls.append(doc)
displacy.serve(doc_ls, style="ent")
# Out:
# /Users/aayushagrawal/anaconda3/lib/python3.7/runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">Hi
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
import spacy
import en_core_web_lg

# %%
import spacy.cli
spacy.cli.download("en_core_web_lg")
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
nlp = en_core_web_lg.load()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-cd055329100b> in <module>
# ----> 1 nlp = en_core_web_lg.load()
#
# ~/anaconda3/lib/python3.7/site-packages/en_core_web_lg/__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model_from_init_py(init_file, **overrides)
#     226     if not model_path.exists():
#     227         raise IOError(Errors.E052.format(path=path2str(data_path)))
# --> 228     return load_model_from_path(data_path, meta, **overrides)
#     229
#     230
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model_from_path(model_path, meta, **overrides)
#     209             component = nlp.create_pipe(factory, config=config)
# ...

# %%
nlp = spacy.load("/Users/aayushagrawal/anaconda3/lib/python3.7/site-packages/en_core_web_lg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-694699cdc095> in <module>
# ----> 1 nlp = spacy.load("/Users/aayushagrawal/anaconda3/lib/python3.7/site-packages/en_core_web_lg")
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/__init__.py in load(name, **overrides)
#      28     if depr_path not in (True, False, None):
#      29         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 30     return util.load_model(name, **overrides)
#      31
#      32
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model(name, **overrides)
#     164             return load_model_from_package(name, **overrides)
#     165         if Path(name).exists():  # path to model data directory
# --> 166             return load_model_from_path(Path(name), **overrides)
#     167     elif hasattr(name, "exists"):  # Path or Path-like to model data
# ...

# %%
model = spacy.load("en_core_web_sm")
model._path
# Out:
# PosixPath('/Users/aayushagrawal/anaconda3/lib/python3.7/site-packages/en_core_web_sm/en_core_web_sm-2.2.5')

# %%
# !ls
# Out:
# BTrees
# BTrees-4.7.2.dist-info
# Babel-2.9.0.dist-info
# Bottleneck-1.3.2.dist-info
# Crypto
# Cython
# Cython-0.29.23.dist-info
# DoubleMetaphone-0.1.dist-info
# Flask-1.1.2.dist-info
# Flask_RESTful-0.3.8.dist-info
# HeapDict-1.0.1.dist-info
# IPython
# Jinja2-2.11.3.dist-info
# Keras_Preprocessing-1.1.2.dist-info
# Levenshtein_search-1.4.5.dist-info
# Levenshtein_search.cpython-37m-darwin.so
# Markdown-3.4.1.dist-info
# MarkupSafe-1.1.1.dist-info
# OpenSSL
# PIL
# Pillow-8.2.0.dist-info
# PyLBFGS-0.2.0.13.dist-info
# PyPDF2
# PyPrint-0.2.6.dist-info
# PyQt5
# PySocks-1.7.1.dist-info
# PyWavelets-1.1.1.dist-info
# PyYAML-5.4.1-py3.7-macosx-10.9-x86_64.egg-info
# Pygments-2.8.1.dist-info
# QDarkStyle-3.0.2.dist-info
# QtAwesome-1.0.2.dist-info
# QtPy-1.9.0.dist-info
# Quandl-3.5.0.dist-info
# README.txt
# Rtree-0.9.7.dist-info
# SQLAlchemy-1.4.7.dist-info
# Send2Trash-1.5.0.dist-info
# Sphinx-1.4.9.dist-info
# Sphinx-3.5.4.dist-info
# Unidecode-0.4.16.dist-info
# ...

# %%
df["labelIds"] = df
# Out:
# 0                           ['CATEGORY_UPDATES', 'INBOX']
# 1       ['Label_86509504764210579', 'CATEGORY_UPDATES'...
# 2       ['Label_86509504764210579', 'Label_68765890314...
# 3       ['Label_4360772061833180153', 'IMPORTANT', 'CA...
# 4       ['UNREAD', 'Label_2234298167017199963', 'CATEG...
#                               ...
# 2224                   ['IMPORTANT', 'CATEGORY_PERSONAL']
# 2225                   ['IMPORTANT', 'CATEGORY_PERSONAL']
# 2226                    ['IMPORTANT', 'CATEGORY_UPDATES']
# 2227                                ['IMPORTANT', 'SENT']
# 2228           ['IMPORTANT', 'CATEGORY_UPDATES', 'INBOX']
# Name: labelIds, Length: 2229, dtype: object

# %%
import pandas as pd
import numpy as np

import re
import ast
import html
import glob
# import spacy
import emoji
import string
import warnings

from datetime import datetime
from string import punctuation

# import pyLDAvis
# import pyLDAvis.sklearn
# pyLDAvis.enable_notebook()
import plotly.express as px
from sklearn.pipeline import Pipeline,FeatureUnion
from sklearn.decomposition import PCA
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.preprocessing import FunctionTransformer
from sklearn.base import TransformerMixin
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import ColumnTransformer

warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
model_id = "sentence-transformers/all-MiniLM-L6-v2"
# model_id = "sentence-transformers/all-mpnet-base-v2"
hf_token = "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"

import requests

api_url = f"https://api-inference.huggingface.co/pipeline/feature-extraction/{model_id}"
headers = {"Authorization": f"Bearer {hf_token}"}

def query(texts):
    response = requests.post(api_url, headers=headers, json={"inputs": texts, "options":{"wait_for_model":True}})
    return response.json()

# %%
body_list = df["body"].fillna("").values.tolist()
chunks = [body_list[x:x+250] for x in range(0, len(body_list), 250)]
print(len(chunks))
print([len(elem) for elem in chunks])
# Out:
# 9
# [250, 250, 250, 250, 250, 250, 250, 250, 229]

# %%
from tqdm import tqdm
res1 = []
for elem in tqdm(chunks):
    res1.extend(query(elem))
# Out:
# 100%|██████████| 9/9 [02:32<00:00, 16.92s/it]

# %%
res1_np = np.array(res1)
res1_np.shape
# Out:
# (2229, 384)

# %%
query_mat = res1_np[:2,:]
query_mat.shape
# Out:
# (2, 384)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
df["best_flight_sim"] = cosine_similarity(query_mat, res1_np).T.max(axis = 1)

# %%
df.sort_values("best_flight_sim", ascending = False)
# Out:
#       Unnamed: 0                id          threadId  \
# 1              1  189de46892b19d42  189de46892b19d42
# 0              0  189de4921223c782  189de4921223c782
# 1055        1055  187d1d8856e0991a  187d1d8856e0991a
# 1054        1054  187d1d8ef3d3b814  187d1d8ef3d3b814
# 989          989  1882f3260830790b  1882f3260830790b
# ...          ...               ...               ...
# 1381        1381  17d63f51676459e2  17d63f51676459e2
# 3              3  189de293a9a424ae  189de293a9a424ae
# 419          419  189a6b4cfc4d79ff  189a6b4cfc4d79ff
# 751          751  1894fc688385d760  1894fc688385d760
# 1351        1351  17f9ced4118c18ff  17f9ced4118c18ff
#
#                                                labelIds  \
# 1     ['Label_86509504764210579', 'CATEGORY_UPDATES'...
# 0                         ['CATEGORY_UPDATES', 'INBOX']
# 1055  ['Label_86509504764210579', 'IMPORTANT', 'CATE...
# 1054                      ['CATEGORY_UPDATES', 'INBOX']
# ...

# %%
import plotly.express as px

# %%
px.histogram(x = df["best_flight_sim"])
# Out:
# <div>
#
#
#             <div id="29b470b7-7456-4ed2-8404-ebf1742ee6d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("29b470b7-7456-4ed2-8404-ebf1742ee6d3")) {
#                     Plotly.newPlot(
#                         '29b470b7-7456-4ed2-8404-ebf1742ee6d3',
# ...

# %%
for elem in df[(df["best_flight_sim"] > 0.6) & (df["best_flight_sim"] < 2)].sort_values("best_flight_sim", ascending = False)["body"]:
    print(elem)
    print("----" * 40)
# Out:
# smartbuy Flight Dear Sunil, Your flight booking through our booking partner YATRA is Successful! Please find your itinerary below. Thank you for choosing us! Booked with For any changes/amendment/queries, kindly reach out to YATRA Call: 0120 484 5562 Email: flightsupport_hdfc@yatra.com Order Details Order ID 44116916512208605388 Order Date 10 Aug 2023 12:37:03 Amount Paid Rs 15,604 Contact Details Partner Ref No 1008230084593 Email aagrawal52@gmail.com Contact Number 7987739914 IndiGo 6E - 7308 JLR HYD Class E Quantity 2 Adult Ticket(s) 0 Child Ticket(s) 0 Infant Ticket(s) Airline PNR XQRKKP 2023-AUG-30 07:55 JLR Jabalpur Terminal :- 2 h 05 min --Via -- 1 Stop 2023-AUG-30 10:00 HYD Hyderabad Terminal :- IndiGo 6E - 551 HYD BLR Class E Quantity 2 Adult Ticket(s) 0 Child Ticket(s) 0 Infant Ticket(s) Airline PNR XQRKKP 2023-AUG-30 14:15 HYD Hyderabad Terminal :- 1 h 10 min --Via -- 1 Stop 2023-AUG-30 15:25 BLR Bangalore Terminal :- 1 Note: NA Passengers Adult 1: Mr. Sunil Agrawal Adult 
# ...

# %%
query_mat = res1_np[df["best_flight_sim"] > 0.65]
query_mat.shape
# Out:
# (14, 384)

# %%
cosine_similarity(query_mat, res1_np).shape
# Out:
# (14, 2229)

# %%
df["best_flight_sim"] = cosine_similarity(query_mat, res1_np).T.max(axis = 1)

# %%
px.histogram(x = df["best_flight_sim"])
# Out:
# <div>
#
#
#             <div id="29bce35e-61d8-4473-bfd1-a058995dba95" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("29bce35e-61d8-4473-bfd1-a058995dba95")) {
#                     Plotly.newPlot(
#                         '29bce35e-61d8-4473-bfd1-a058995dba95',
# ...

# %%
for elem in df[(df["best_flight_sim"] > 0.65) & (df["best_flight_sim"] < 2)].sort_values("best_flight_sim", ascending = False)["body"]:
    print(elem)
    print("----" * 40)
# Out:
# PNR/Booking Ref.: XQRKKP Status Date of Booking* Payment Status CONFIRMED 10Aug23 07:08:23 (UTC) Approved *Booking Date reflects in UTC (Universal Time Coordinated), all other timings mentioned are as per Local Time. IndiGo Passenger - 1/ 2 IndiGo Flight(s) Mr.SunilAgrawal Date From (Terminal) Departs Flight Number (Aircraft type) Check-in/Bag drop closes To (Terminal) Arrives Via 30 Aug 23 Jabalpur 07:55 6E 7308 06:55 Hyderabad 10:00 IndiGo Flight(s) Mr.SunilAgrawal Date From (Terminal) Departs Flight Number (Aircraft type) Check-in/Bag drop closes To (Terminal) Arrives Via 30 Aug 23 Hyderabad 14:15 6E 551 ( A321) 13:15 Bengaluru (T 1) 15:25 Status Date of Booking* Payment Status CONFIRMED 10Aug23 07:08:23 (UTC) Approved *Booking Date reflects in UTC (Universal Time Coordinated), all other timings mentioned are as per Local Time. IndiGo Passenger - 2/ 2 IndiGo Flight(s) Mrs.MamtaAgrawal Date From (Terminal) Departs Flight Number (Aircraft type) Check-in/Bag drop closes To (Terminal)
# ...

# %%
query_mat = res1_np[df["best_flight_sim"] > 0.65]
print(query_mat.shape)

df["best_flight_sim"] = cosine_similarity(query_mat, res1_np).T.max(axis = 1)
px.histogram(x = df["best_flight_sim"])
# Out:
# (18, 384)
# <div>
#
#
#             <div id="feaec07f-9e26-4d8e-bed1-910e244e595a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("feaec07f-9e26-4d8e-bed1-910e244e595a")) {
#                     Plotly.newPlot(
#                         'feaec07f-9e26-4d8e-bed1-910e244e595a',
# ...

# %%
for elem in df[(df["best_flight_sim"] > 0.75) & (df["best_flight_sim"] < 2)].sort_values("best_flight_sim", ascending = False)["body"]:
    print(elem)
    print("----" * 40)
# Out:
# PNR/Booking Ref.: XQRKKP Status Date of Booking* Payment Status CONFIRMED 10Aug23 07:08:23 (UTC) Approved *Booking Date reflects in UTC (Universal Time Coordinated), all other timings mentioned are as per Local Time. IndiGo Passenger - 1/ 2 IndiGo Flight(s) Mr.SunilAgrawal Date From (Terminal) Departs Flight Number (Aircraft type) Check-in/Bag drop closes To (Terminal) Arrives Via 30 Aug 23 Jabalpur 07:55 6E 7308 06:55 Hyderabad 10:00 IndiGo Flight(s) Mr.SunilAgrawal Date From (Terminal) Departs Flight Number (Aircraft type) Check-in/Bag drop closes To (Terminal) Arrives Via 30 Aug 23 Hyderabad 14:15 6E 551 ( A321) 13:15 Bengaluru (T 1) 15:25 Status Date of Booking* Payment Status CONFIRMED 10Aug23 07:08:23 (UTC) Approved *Booking Date reflects in UTC (Universal Time Coordinated), all other timings mentioned are as per Local Time. IndiGo Passenger - 2/ 2 IndiGo Flight(s) Mrs.MamtaAgrawal Date From (Terminal) Departs Flight Number (Aircraft type) Check-in/Bag drop closes To (Terminal)
# ...

# %%
query_mat = res1_np[df["best_flight_sim"] > 0.65]
print(query_mat.shape)

df["best_flight_sim"] = cosine_similarity(query_mat, res1_np).T.max(axis = 1)
px.histogram(x = df["best_flight_sim"])
# Out:
# (19, 384)
# <div>
#
#
#             <div id="ff22ac01-fdf0-43d7-9bf6-2207bf4e7721" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ff22ac01-fdf0-43d7-9bf6-2207bf4e7721")) {
#                     Plotly.newPlot(
#                         'ff22ac01-fdf0-43d7-9bf6-2207bf4e7721',
# ...

# %%
for elem in df[(df["best_flight_sim"] > 0.63) & (df["best_flight_sim"] < 2)].sort_values("best_flight_sim", ascending = False)["body"]:
    print(elem)
    print("----" * 40)
# Out:
# PNR/Booking Ref.: XQRKKP Status Date of Booking* Payment Status CONFIRMED 10Aug23 07:08:23 (UTC) Approved *Booking Date reflects in UTC (Universal Time Coordinated), all other timings mentioned are as per Local Time. IndiGo Passenger - 1/ 2 IndiGo Flight(s) Mr.SunilAgrawal Date From (Terminal) Departs Flight Number (Aircraft type) Check-in/Bag drop closes To (Terminal) Arrives Via 30 Aug 23 Jabalpur 07:55 6E 7308 06:55 Hyderabad 10:00 IndiGo Flight(s) Mr.SunilAgrawal Date From (Terminal) Departs Flight Number (Aircraft type) Check-in/Bag drop closes To (Terminal) Arrives Via 30 Aug 23 Hyderabad 14:15 6E 551 ( A321) 13:15 Bengaluru (T 1) 15:25 Status Date of Booking* Payment Status CONFIRMED 10Aug23 07:08:23 (UTC) Approved *Booking Date reflects in UTC (Universal Time Coordinated), all other timings mentioned are as per Local Time. IndiGo Passenger - 2/ 2 IndiGo Flight(s) Mrs.MamtaAgrawal Date From (Terminal) Departs Flight Number (Aircraft type) Check-in/Bag drop closes To (Terminal)
# ...

# %%
for elem in df[(df["best_flight_sim"] > 0.5) & (df["best_flight_sim"] < 0.63)].sort_values("best_flight_sim", ascending = False)["body"]:
    print(elem)
    print("----" * 40)
# Out:
# BookMyShow Your booking is confirmed! Booking ID WKBBZML Avatar: The Way of Water (3D) (U/A) 06:10pm | Sat, 29 Apr, 2023 Cinepolis: Nexus Shantiniketan, Bengaluru(JUNIOR) Bengaluru, Bengaluru DOUBLE S - D5 JUNIOR Check your booking details, discounts, deals and much more with your ticket Open ticket Note: Please follow the covid/safety guidelines (As per the directions from your local authority) OTHER ITEMS BookASmile BookASmile QTY 1 ORDER SUMMARY TICKET AMOUNT Quantity Rs.375.00 1 ticket Convenience fees Base Amount Integrated GST (IGST) @ 18% Rs.51.92 Rs.44.00 Rs.7.92 OTHER ITEMS Rs.1.00 AMOUNT PAID Rs.427.92 Booking Date & Time Sat, 29 Apr, 2023 | 09:26am Payment Type Credit Card/Debit Card Confirmation# 1951430 IMPORTANT INSTRUCTIONS This transaction cannot be cancelled as per cinema cancellation policy. The Credit Card and Credit Card Holder must be present at the ticket counter while collecting the ticket(s). GST collected is paid to the department. 999799 - Other Services n.e
# ...

# %%
# !pip install --upgrade networkx
# Out:
# ...
#      |████████████████████████████████| 1.9 MB 1.0 MB/s eta 0:00:01
# ...
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.5
#     Uninstalling networkx-2.5:
#       Successfully uninstalled networkx-2.5
# ...

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
import matplotlib.pyplot as plt

# Sample email IDs
email_ids = [
    "user1@example.com",
    "user2@example.com",
    "user3@example.com",
    # ... add more email IDs ...
]

# Step 1: TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(email_ids)

# Step 2: Calculate Distances (Cosine Similarity)
distances = 1 - cosine_similarity(tfidf_matrix)

# Step 3: Create Graph
G = nx.Graph()

# Add nodes (email IDs) to the graph
for idx, email_id in enumerate(email_ids):
    G.add_node(idx, label=email_id)

# Add edges (distances) to the graph
num_email_ids = len(email_ids)
for i in range(num_email_ids):
    for j in range(i + 1, num_email_ids):
        distance = distances[i][j]
        G.add_edge(i, j, weight=distance)

# Step 4: Visualize the Graph
pos = nx.spring_layout(G, seed = 42)  # Layout algorithm
labels = nx.get_node_attributes(G, "label")

nx.draw(G, pos, labels=labels, with_labels=True, font_weight="bold")
edge_labels = {(i, j): f"{d:.2f}" for (i, j, d) in G.edges(data="weight")}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     395            return random_state.rand()
# --> 396
#     397        @py_random_state(0)
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-89-edc3e50cd8c2> in <module>
#      35
#      36 # Step 4: Visualize the Graph
# ---> 37 pos = nx.spring_layout(G, seed = 42)  # Layout algorithm
#      38 labels = nx.get_node_attributes(G, "label")
#      39
#
# ~/anaconda3/lib/python3.7/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# ...

# %%
distances
# Out:
# array([[0.        , 0.58904791, 0.58904791],
#        [0.58904791, 0.        , 0.58904791],
#        [0.58904791, 0.58904791, 0.        ]])
