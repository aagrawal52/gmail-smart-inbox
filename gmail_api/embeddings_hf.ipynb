# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("emails_dir/emails_parsed.csv")
df.head()
# Out:
#    Unnamed: 0                id          threadId  \
# 0           0  1886c44e3eacd1bd  1886c44e3eacd1bd
# 1           1  1886c0dde71b424d  1886b089720e7a16
# 2           2  1886c01327dbc5f7  1886a9354f28a315
# 3           3  1886becb5c7e7f55  1886a9354f28a315
# 4           4  1886bdce3bb4c278  1886a9354f28a315
#
#                                             labelIds  \
# 0  ['Label_7781807634347615867', 'CATEGORY_UPDATE...
# 1  ['UNREAD', 'Label_3265720468738706690', 'CATEG...
# 2  ['UNREAD', 'Label_5479026944618646578', 'CATEG...
# 3  ['UNREAD', 'Label_5479026944618646578', 'CATEG...
# 4  ['UNREAD', 'Label_5479026944618646578', 'CATEG...
#
#                                              snippet  \
# 0  Senior Quantitative Researcher and other roles...
# 1  Message for Aayush Agrawal Dear Investor, Foli...
# 2  Dear AAYUSH, Following is/are the list of tran...
# 3  Dear AAYUSH, Following is/are the list of tran...
# 4  Dear AAYUSH, Following is/are the list of tran...
#
# ...

# %%
# Out:
# array(['Senior Quantitative Researcher and other roles are available ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏',
#        'Message for Aayush Agrawal Dear Investor, Folio no.: 1016796170 Thank you for choosing Aditya Birla Sun Life Mutual Fund as your investment partner. All your e-statements are password protected. Please',
#        'Dear AAYUSH, Following is/are the list of transactions for your Demat account ending with *23354467 Sr. No. Company Name ISIN Quantity Debit / Credit Date and Time 1 CUMMINS INDIA LIMITED - EQUITY',
#        ...,
#        'Dear Student, Welcome to Flytech Aviation Academy Become a Pilot No bird soars too high if he soars',
#        'mausa ji sirf abhi 1 week ka hi time table banaya huin. agar follow kar paaya toh main aage ka bhi',
#        'होली आई, सतरंगी रंगो की बौछार लाई, ढेर सारी मिठाई और प्यार लाई, आपकी ज़िंदगी हो मिठे प्यार और खुशियों'],
# ...

# %%
model_id = "papluca/xlm-roberta-base-language-detection"
hf_token = "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"

import requests

api_url = f"https://api-inference.huggingface.co/pipeline/feature-extraction/{model_id}"
headers = {"Authorization": f"Bearer {hf_token}"}

def query(texts):
    response = requests.post(api_url, headers=headers, json={"inputs": texts, "options":{"wait_for_model":True}})
    return response.json()

# %%
len(query(['होली आई, सतरंगी रंगो की बौछार लाई, ढेर सारी मिठाई और प्यार लाई, आपकी ज़िंदगी हो मिठे प्यार और खुशियों'])[0][1])
# Out:
# 768

# %%
query(['होली आई, सतरंगी रंगो की बौछार लाई, ढेर सारी मिठाई और प्यार लाई, आपकी ज़िंदगी हो मिठे प्यार और खुशियों'])
# Out:
# [[[[0.8436115384101868,
#     -0.20585237443447113,
#     -0.003501355415210128,
#     -1.155294418334961,
#     -0.9514307379722595,
#     -0.74242103099823,
#     -0.6900420784950256,
#     -0.4111403524875641,
#     0.19863806664943695,
#     0.15397648513317108,
#     -0.6875631213188171,
#     0.40182653069496155,
#     0.8450589179992676,
#     1.7719920873641968,
#     0.5318071842193604,
#     -0.5719701051712036,
#     0.5805383920669556,
#     0.2942069470882416,
#     0.2189604640007019,
#     0.5481584668159485,
#     0.9730566740036011,
#     -0.2563271224498749,
#     0.5246606469154358,
#     -0.16501696407794952,
#     -0.838520348072052,
#     1.3135913610458374,
#     0.5485038757324219,
#     -1.282010555267334,
#     -0.3328128755092621,
#     0.008819499053061008,
#     0.3801666498184204,
#     0.7641691565513611,
#     0.18977998197078705,
#     -0.9017133116722107,
#     -0.3321034014225006,
#     0.04553605988621712,
#     -0.5308117270469666,
# ...
